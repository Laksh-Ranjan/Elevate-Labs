# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\data science\\python\\elevate labs intern\\task 5\\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_51432\286566303.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#b  pairplot
col=df.columns
# Plot
sns.pairplot(df[col])
plt.show()

# %% [markdown]
# EXPLAINATION

# %%
"""
On the above pairplot we have used Age, Fare, SibSp, Parch, colored by Survival 
and Survivors (red) often have slightly higher fares
Age distribution is very wide for both survived and non-survived
SibSp and Parch are mostly low numbers between (0-2)
"""
# Out:
# '\nOn the above pairplot we have used Age, Fare, SibSp, Parch, colored by Survival \nand Survivors (red) often have slightly higher fares\nAge distribution is very wide for both survived and non-survived\nSibSp and Parch are mostly low numbers between (0-2)\n'

# %%
cols = df.select_dtypes(include=['float64', 'int64'])
cols
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3  28.0      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#b  Plot heatmap

cols = df.select_dtypes(include=['float64', 'int64'])

corr = cols.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Titanic Dataset')
plt.show()

# %% [markdown]
# EXPLAINATION

# %%
"""
On the above Heatmap show how strongly variables are correlated
Fare and Survival have a positive correlation (~0.26)
SibSp and Parch are positively related (people traveling with family)
Age has very little correlation to Survival
"""
# Out:
# '\nOn the above Heatmap show how strongly variables are correlated\nFare and Survival have a positive correlation (~0.26)\nSibSp and Parch are positively related (people traveling with family)\nAge has very little correlation to Survival\n'

# %%
#d boxplot

sns.boxplot(x=df['Fare'])
plt.title("Box Plot of Fare")
plt.xlabel("Fare")
plt.show()

# %% [markdown]
# EXPLAINATION

# %%
"""
On the above Boxplot Compares the age distribution of survived vs non-survived
Median age of survivors is a little lower than non-survivors
Some very old survivors are outliers
"""
# Out:
# '\nOn the above Boxplot Compares the age distribution of survived vs non-survived\nMedian age of survivors is a little lower than non-survivors\nSome very old survivors are outliers\n'

# %%
#d histro 
plt.figure(figsize=(8,6))
histogram_fig = sns.histplot(df["Age"], bins=30, kde=True, color='skyblue')
plt.title("Histogram of Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# EXPLAINATION

# %%
"""
On the abpve Graph show Distribution of ages overall
Huge number of passengers are between 20–40 years old
Some younger and older passengers exist but fewer
"""

# %%
#d
SibSp_count=df['SibSp'].value_counts()

plt.scatter(SibSp_count.index,SibSp_count.values)
plt.title('SCATTER Plot')
plt.xlabel('SibSp')
plt.ylabel('Values_Counts')
plt.legend()
plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_51432\1035397448.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# EXPLAINATION

# %%
"""
On the above scatter Graph show  how Age and Fare relate to Survival
Passengers who paid higher fares had a higher chance to survive
Young and very old passengers are scattered everywhere
"""
# Out:
# '\nOn the above scatter Graph show  how Age and Fare relate to Survival\nPassengers who paid higher fares had a higher chance to survive\nYoung and very old passengers are scattered everywhere\n'
